# %% [markdown]
# <a href="https://colab.research.google.com/github/gabru8744/GRIP-task-1/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-colab

# %%
from google.colab import drive 
drive.mount ('/content/drive')
# !ln -s /content/gdrive/My\ Drive / /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/drive
# ln: target '/mydrive' is not a directory
# ls: cannot access '/mydrive': No such file or directory

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14665, done.
# remote: Total 14665 (delta 0), reused 0 (delta 0), pack-reused 14665
# Receiving objects: 100% (14665/14665), 13.25 MiB | 23.73 MiB/s, done.
# Resolving deltas: 100% (9977/9977), done.

# %%
# !make
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# %cd darknet 
# !sed -i 's/OPENCV=0/OPENCV=1' Makefile
# !sed -i 's/GPU=0/GPU=1' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1' Makefile
# !make
# Out:
# /content/darknet
# sed: -e expression #1, char 19: unterminated `s' command
# sed: -e expression #1, char 13: unterminated `s' command
# sed: -e expression #1, char 17: unterminated `s' command
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ...

# %%
# !cp darknet/cfg/yolov3.cfg darknet/cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' darknet/cfg/yolov3_training.cfg
# !sed -i 's/subdrivisions=1/subdrivisions=16/' darknet/cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' darknet/cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' darknet/cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' darknet/cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' darknet/cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@classes=21@' darknet/cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@classes=21@' darknet/cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@classes=21@' darknet/cfg/yolov3_training.cfg

# %%
# !echo -e 'Wearing Mask/nNot Wearing Mask' > darknet/data/obj.names

# %%
# !echo -e 'classses= 2\n train = data/train.txt\n valid = data/test.txt\n names = data/obj.names\n backup =/mydrive/yolov3' > darknet/data/obj.data

# %%
# !cp darknet/cfg/yolov3_training.cfg /content/drive/MyDrive/yolov3/yolov3_testing.cfg
# !cp darknet/data/obj.names /content/drive/MyDrive/yolov3/classes.txt

# %%
# !mkdir darknet/data/obj

# %%
# !unzip -uq "/content/drive/MyDrive/yolov3/images1.zip" -d darknet/data/obj

# %%
import glob
images_list = glob.glob("darknet/data/obj/*.jpg")
with open("darknet/data/train.txt","w") as f:
  f.write("\n".join(images_list) )

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-01-19 22:42:33--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  9.23MB/s    in 17s
#
# 2021-01-19 22:42:51 (9.16 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
#!./darknet detector train data/obj.data cfg/yolo3_training.cfg darknet53.conv.74 -dont_show
#!./darknet dectector train data/obj.data cfg/yolov3_training.cfg /MyDrive/yolov3/yolov3_training_last.weight -dont_show
# Out:
#   File "<ipython-input-40-1db55acd4fe3>", line 2
#     get_ipython().system('./darknet dectector train data/obj.data cfg/yolov3_training.cfg /MyDrive/yolov3/yolov3_training_last.weight ')
#     ^
# IndentationError: unexpected indent

# %%
# !nvidia-smi
# Out:
# Tue Jan 19 22:07:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...
